# %%
# !pip install pandas
# !pip install dtale
# Out:
# Requirement already satisfied: pandas in /home/kawshikcvit/miniconda3/envs/myenv/lib/python3.8/site-packages (2.0.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/kawshikcvit/miniconda3/envs/myenv/lib/python3.8/site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /home/kawshikcvit/miniconda3/envs/myenv/lib/python3.8/site-packages (from pandas) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in /home/kawshikcvit/miniconda3/envs/myenv/lib/python3.8/site-packages (from pandas) (2023.3)
# Requirement already satisfied: numpy>=1.20.3 in /home/kawshikcvit/miniconda3/envs/myenv/lib/python3.8/site-packages (from pandas) (1.24.3)
# Requirement already satisfied: six>=1.5 in /home/kawshikcvit/miniconda3/envs/myenv/lib/python3.8/site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Requirement already satisfied: dtale in /home/kawshikcvit/miniconda3/envs/myenv/lib/python3.8/site-packages (3.5.0)
# Requirement already satisfied: dash-colorscales in /home/kawshikcvit/miniconda3/envs/myenv/lib/python3.8/site-packages (from dtale) (0.0.4)
# Requirement already satisfied: dash-daq in /home/kawshikcvit/miniconda3/envs/myenv/lib/python3.8/site-packages (from dtale) (0.5.0)
# Requirement already satisfied: Flask-Compress in /home/kawshikcvit/miniconda3/envs/myenv/lib/python3.8/site-packages (from dtale) (1.14)
# Requirement already satisfied: future>=0.14.0 in /home/kawshikcvit/miniconda3/envs/myenv/lib/python3.8/site-packages (from dtale) (0.18.3)
# Requirement already satisfied: kaleido in /home/kawshikcvit/miniconda3/envs/myenv/lib/python3.8/site-packages (from dtale) (0.2.1)
# Requirement already satisfied: missingno in /home/kawshikcvit/miniconda3/envs/myenv/lib/python3.8/site-packages (from dtale) (0.5.2)
# Requirement already satisfied: pandas in /home/kawshikcvit/miniconda3/envs/myenv/lib/python3.8/site-packages (from dtale) (2.0.3)
# Requirement already satisfied: squarify in /home/kawshikcvit/miniconda3/envs/myenv/lib/python3.8/site-packages (from dtale) (0.4.3)
# Requirement already satisfied: strsimpy in /home/kawshikcvit/miniconda3/envs/myenv/lib/python3.8/site-packages (from dtale) (0.2.1)
# Requirement already satisfied: six in /home/kawshikcvit/miniconda3/envs/myenv/lib/python3.8/site-packages (from dtale) (1.16.0)
# Requirement already satisfied: xlrd in /home/kawshikcvit/miniconda3/envs/myenv/lib/python3.8/site-packages (from dtale) (2.0.1)
# Requirement already satisfied: matplotlib<=3.7.2 in /home/kawshikcvit/miniconda3/envs/myenv/lib/python3.8/site-packages (from dtale) (3.7.2)
# Requirement already satisfied: scipy<=1.10.1 in /home/kawshikcvit/miniconda3/envs/myenv/lib/python3.8/site-packages (from dtale) (1.10.1)
# Requirement already satisfied: beautifulsoup4 in /home/kawshikcvit/miniconda3/envs/myenv/lib/python3.8/site-packages (from dtale) (4.12.2)
# Requirement already satisfied: certifi in /home/kawshikcvit/miniconda3/envs/myenv/lib/python3.8/site-packages (from dtale) (2023.7.22)
# Requirement already satisfied: cycler in /home/kawshikcvit/miniconda3/envs/myenv/lib/python3.8/site-packages (from dtale) (0.11.0)
# Requirement already satisfied: flask-ngrok in /home/kawshikcvit/miniconda3/envs/myenv/lib/python3.8/site-packages (from dtale) (0.0.25)
# Requirement already satisfied: lz4 in /home/kawshikcvit/miniconda3/envs/myenv/lib/python3.8/site-packages (from dtale) (4.3.2)
# Requirement already satisfied: dash-bootstrap-components<=1.3.1 in /home/kawshikcvit/miniconda3/envs/myenv/lib/python3.8/site-packages (from dtale) (1.3.1)
# Requirement already satisfied: seaborn in /home/kawshikcvit/miniconda3/envs/myenv/lib/python3.8/site-packages (from dtale) (0.12.2)
# Requirement already satisfied: networkx in /home/kawshikcvit/miniconda3/envs/myenv/lib/python3.8/site-packages (from dtale) (3.1)
# Requirement already satisfied: scikit-learn in /home/kawshikcvit/miniconda3/envs/myenv/lib/python3.8/site-packages (from dtale) (1.3.1)
# Requirement already satisfied: statsmodels in /home/kawshikcvit/miniconda3/envs/myenv/lib/python3.8/site-packages (from dtale) (0.14.0)
# Requirement already satisfied: numpy in /home/kawshikcvit/miniconda3/envs/myenv/lib/python3.8/site-packages (from dtale) (1.24.3)
# Requirement already satisfied: openpyxl!=3.2.0b1 in /home/kawshikcvit/miniconda3/envs/myenv/lib/python3.8/site-packages (from dtale) (3.1.2)
# Requirement already satisfied: xarray in /home/kawshikcvit/miniconda3/envs/myenv/lib/python3.8/site-packages (from dtale) (2023.1.0)
# Requirement already satisfied: dash in /home/kawshikcvit/miniconda3/envs/myenv/lib/python3.8/site-packages (from dtale) (2.13.0)
# Requirement already satisfied: et-xmlfile in /home/kawshikcvit/miniconda3/envs/myenv/lib/python3.8/site-packages (from dtale) (1.1.0)
# Requirement already satisfied: plotly in /home/kawshikcvit/miniconda3/envs/myenv/lib/python3.8/site-packages (from dtale) (5.17.0)
# Requirement already satisfied: Flask<2.3 in /home/kawshikcvit/miniconda3/envs/myenv/lib/python3.8/site-packages (from dtale) (2.2.5)
# Requirement already satisfied: itsdangerous in /home/kawshikcvit/miniconda3/envs/myenv/lib/python3.8/site-packages (from dtale) (2.1.2)
# Requirement already satisfied: requests in /home/kawshikcvit/miniconda3/envs/myenv/lib/python3.8/site-packages (from dtale) (2.31.0)
# Requirement already satisfied: werkzeug<2.3 in /home/kawshikcvit/miniconda3/envs/myenv/lib/python3.8/site-packages (from dtale) (2.2.3)
# Requirement already satisfied: dash-html-components==2.0.0 in /home/kawshikcvit/miniconda3/envs/myenv/lib/python3.8/site-packages (from dash->dtale) (2.0.0)
# Requirement already satisfied: dash-core-components==2.0.0 in /home/kawshikcvit/miniconda3/envs/myenv/lib/python3.8/site-packages (from dash->dtale) (2.0.0)
# Requirement already satisfied: dash-table==5.0.0 in /home/kawshikcvit/miniconda3/envs/myenv/lib/python3.8/site-packages (from dash->dtale) (5.0.0)
# Requirement already satisfied: typing-extensions>=4.1.1 in /home/kawshikcvit/miniconda3/envs/myenv/lib/python3.8/site-packages (from dash->dtale) (4.7.1)
# Requirement already satisfied: retrying in /home/kawshikcvit/miniconda3/envs/myenv/lib/python3.8/site-packages (from dash->dtale) (1.3.4)
# Requirement already satisfied: ansi2html in /home/kawshikcvit/miniconda3/envs/myenv/lib/python3.8/site-packages (from dash->dtale) (1.8.0)
# Requirement already satisfied: nest-asyncio in /home/kawshikcvit/miniconda3/envs/myenv/lib/python3.8/site-packages (from dash->dtale) (1.5.6)
# Requirement already satisfied: setuptools in /home/kawshikcvit/miniconda3/envs/myenv/lib/python3.8/site-packages (from dash->dtale) (68.0.0)
# Requirement already satisfied: Jinja2>=3.0 in /home/kawshikcvit/miniconda3/envs/myenv/lib/python3.8/site-packages (from Flask<2.3->dtale) (3.1.2)
# Requirement already satisfied: click>=8.0 in /home/kawshikcvit/miniconda3/envs/myenv/lib/python3.8/site-packages (from Flask<2.3->dtale) (8.1.7)
# Requirement already satisfied: importlib-metadata>=3.6.0 in /home/kawshikcvit/miniconda3/envs/myenv/lib/python3.8/site-packages (from Flask<2.3->dtale) (6.8.0)
# Requirement already satisfied: contourpy>=1.0.1 in /home/kawshikcvit/miniconda3/envs/myenv/lib/python3.8/site-packages (from matplotlib<=3.7.2->dtale) (1.1.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/kawshikcvit/miniconda3/envs/myenv/lib/python3.8/site-packages (from matplotlib<=3.7.2->dtale) (4.42.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /home/kawshikcvit/miniconda3/envs/myenv/lib/python3.8/site-packages (from matplotlib<=3.7.2->dtale) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /home/kawshikcvit/miniconda3/envs/myenv/lib/python3.8/site-packages (from matplotlib<=3.7.2->dtale) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in /home/kawshikcvit/miniconda3/envs/myenv/lib/python3.8/site-packages (from matplotlib<=3.7.2->dtale) (9.4.0)
# Requirement already satisfied: pyparsing<3.1,>=2.3.1 in /home/kawshikcvit/miniconda3/envs/myenv/lib/python3.8/site-packages (from matplotlib<=3.7.2->dtale) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /home/kawshikcvit/miniconda3/envs/myenv/lib/python3.8/site-packages (from matplotlib<=3.7.2->dtale) (2.8.2)
# Requirement already satisfied: importlib-resources>=3.2.0 in /home/kawshikcvit/miniconda3/envs/myenv/lib/python3.8/site-packages (from matplotlib<=3.7.2->dtale) (6.1.0)
# Requirement already satisfied: tenacity>=6.2.0 in /home/kawshikcvit/miniconda3/envs/myenv/lib/python3.8/site-packages (from plotly->dtale) (8.2.3)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /home/kawshikcvit/miniconda3/envs/myenv/lib/python3.8/site-packages (from werkzeug<2.3->dtale) (2.1.1)
# Requirement already satisfied: soupsieve>1.2 in /home/kawshikcvit/miniconda3/envs/myenv/lib/python3.8/site-packages (from beautifulsoup4->dtale) (2.5)
# Requirement already satisfied: brotli in /home/kawshikcvit/miniconda3/envs/myenv/lib/python3.8/site-packages (from Flask-Compress->dtale) (1.1.0)
# Requirement already satisfied: pytz>=2020.1 in /home/kawshikcvit/miniconda3/envs/myenv/lib/python3.8/site-packages (from pandas->dtale) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in /home/kawshikcvit/miniconda3/envs/myenv/lib/python3.8/site-packages (from pandas->dtale) (2023.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/kawshikcvit/miniconda3/envs/myenv/lib/python3.8/site-packages (from requests->dtale) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /home/kawshikcvit/miniconda3/envs/myenv/lib/python3.8/site-packages (from requests->dtale) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/kawshikcvit/miniconda3/envs/myenv/lib/python3.8/site-packages (from requests->dtale) (1.26.16)
# Requirement already satisfied: joblib>=1.1.1 in /home/kawshikcvit/miniconda3/envs/myenv/lib/python3.8/site-packages (from scikit-learn->dtale) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /home/kawshikcvit/miniconda3/envs/myenv/lib/python3.8/site-packages (from scikit-learn->dtale) (3.2.0)
# Requirement already satisfied: patsy>=0.5.2 in /home/kawshikcvit/miniconda3/envs/myenv/lib/python3.8/site-packages (from statsmodels->dtale) (0.5.3)
# Requirement already satisfied: zipp>=0.5 in /home/kawshikcvit/miniconda3/envs/myenv/lib/python3.8/site-packages (from importlib-metadata>=3.6.0->Flask<2.3->dtale) (3.17.0)

# %% [markdown]
# ## Mathematically formulating Coreference Resolution:
#
# $t$ : Current time-step or mention
#
# $M^t$: List of Mentions sorted by position**
#
# $m_t$:  $t^{th}$ mention in $M$**
#
#  ****
#
# $E^t$: List of Entities/Clusters sorted by position**
#
# $E_{i,k}^t:$ $k^{th}$ $**k^{th}$$i^{th}$  entity in $E^t$**
#
# $L_{E^t} = L_t$ : **Length of $E^t$ (Number of Entities)**
#
# $Err_{i}^t:$  **A list containing mentions of entity  $i$, where a decision error occurred.(Should have been mapped to $i$ but the model didn’t).**
#
#  ****
#
# $C_{ik}^{t}$ : $k^{th}$  mention (rep. by string) of the $i^{th}$ entity
#
# $e_{m_t}$ : Entity to which $m_t$ belongs as per the ground truth
#
# $\bar{e}_{m_t}$ : Entity to which $m_t$ is mapped by the model
#
# $F$: Entity Ranking MLP
#
# $T$: End time
#  ****
#
#
# ### **Conditions:**
#
# 1. $e_{m_t} == \bar e_{m_t}$ ::: No error
# 2. $e_{m_t} \neq \bar e_{m_t}:$
#     1. $e_{m_t} == L_t+1$  and $\bar e_{m_t} <= L_t$
#         1. **Name:** o_c error
#         2. **Ground truth:** Create a new entity
#         3. **Action:** Map to an existing entity
#     2. $e_{m_t} \leq L_t$ and $\bar e_{m_t} == L_t+1$
#         1. **Name:** c_o error
#         2. **Ground truth:** Map to an existing entity
#         3. **Action:** Create a new entity
#     3. $e_{m_t} \leq L_t$  and $\bar e_{m_t} \leq L_t$
#         1. **Name:** c_c error
#         2. **Ground truth:** Map to entity $e_{m_{t}}$
#         3. **Action:** Map to entity **$\bar e_{m_t}$**
#
#  ****
#
# ### Recorded Data:
#
# **Intuitive:**
#
# - **doc_key:** Document id of the document
# - **decision_type:** `o` or `c`
# - **no_error: `0`** if there is an error else **`1`**
# - **detailed_error_type:** `o_c` (`o` error type) & [ `c_o` and `c_c` ] ( `c` error type)
# - **mention_ind:** Index of mention in $M$
# - **entity_ind:** Index of the entity in $E^T = E$
# - **entity_len: $L_t$**
# - **category:** [`PROP`, `PRON`, `NOM`]
# - **antecedent_ind:** $E_{e_{m_t},-1}$
# - **mapped_antecedent_ind:** $E_{\bar e_{m_t},-1}$
# - **antecedent_category:** Of mention $m_t$: $category(C_{e_{m_t},-1})$
# - **mapped_antecedent_category:** Of mention  $m_t$ mapped to entity  $\bar{e}_{m_t}$: $category(C_{\bar{e}_{m_t},-1})$
# - **type:** [ `PER`, `FAC`, `LOC`, `GPE`, `VEH`, `ORG` ]
# - **mapped_antecedent_type:** Of mention $m_t$ mapped to entity $\bar{e}_{m_t}$: $type(C_{\bar{e}_{m_t},-1})$
# - **mention_str**: String representation of a mention
# - **cluster_str:** Let mention be $m_t$ ,
#
#      $cluster\_str(m_t,t)$ = {$k\_count(C_{e_{m_t}}^t,k)$ for $k$  in $set(C_{e_{m_t}}^t)$}, i.e. concatenation of unique mention strings and the number of occurences till time t.
#
#     - Example:  {mr. villars_1 my good sir_1 you_9 your_2 dear sir_1}: There are 9 instances of you in the cluster
# - **mapped_cluster_str:** Let mention be $m_t$ mapped to entity $\bar e_{m_t}$, $mapped\_cluster\_str(m_t)$ = { $k\_count(C_{\bar e_{m_t}}^t,k)$ for $k$ in $set(C_{\bar e_{m_t}}^t)$}
#
# **Calculated for mention $m_t$:**
#
# - **antecedent_dist** : $t - E_{e_{m_{t}},-1}^t -1$
# - **mapped_antecedant_dist** : $t - E_{\bar e_{m_{t}},-1}^t -1$
# - antecedent_dist_ent : Number of unique entities between antecedent and the current index.
# - mapped_antecedent_dist_ent : Number of unique entities between mapped_antecedent and the current index.
# - **cluster_size**: For mention $m_t$ : $|E_{e_{m_t}}^t|$
# - **mapped_cluster_size**: For mention $m_t$  : $|E_{\bar e_{m_t}}^t|$
# - **cluster_errors**:  For mention $m_t$ : $|Err_{e_{m_t}}^t|$
# - **mapped_cluster_err**: For mention $m_t$ : $|Err_{\bar e_{m_t}}^t|$
# - **{mapped/cluster}_props:** Fraction of proper nouns in **{mapped/cluster}** Cluster
# - **{mapped/cluster}_prons:** Fraction of pronouns in **{mapped/cluster}** Cluster
# - **{mapped/cluster}_noms:** Fraction of nominals in **{mapped/cluster}** Cluster
# - **entity_score:** For mention $m_t$ : $F(m_t,e_{m_t})$
# - **wrong_score:** For mention $m_i$ : $F(m_t,\bar e_{m_t})$
# - **num_wrong_inst: $\sum_{k = 1}^{L_t+1} 1(F(m_t, e_k) >  F(m_t, e_{m_i})), where\ F(m_{t}, e_{L_t+1}) = 0$**
# - **wrong_mean_score**: ( $\frac{\sum_{k = 1}^{L_t+1}F(m_t, e_k) \cdot 1(F(m_t, e_k) >  F(m_t, e_{m_i}))}{num\_wrong\_inst}$)
# - **entropy:** $-\sum_{k=1}^{L_t+1} P_k \cdot \log(P_k)$  where $P_k$  is the probability of assigning $m_t$ to entity $k$
# - **cluster_final_size:** $|E_{e_{m_i}}^T|$
# - **mapped_cluster_final_size**: $|E_{\bar e_{m_i}}^T|$
# - **[LingMess](https://arxiv.org/pdf/2205.12644.pdf)** adapted to Entity Space:
#
#     ```python
#     PRONOUNS_GROUPS = {
#                 'i': 0, 'me': 0, 'my': 0, 'mine': 0, 'myself': 0, "i.":0,
#                 'you': 1, 'your': 1, 'yours': 1, 'yourself': 1, 'yourselves': 1, "thou":1,
#                 'he': 2, 'him': 2, 'his': 2, 'himself': 2,
#                 'she': 3, 'her': 3, 'hers': 3, 'herself': 3,
#                 'it': 4, 'its': 4, 'itself': 4,
#                 'we': 5, 'us': 5, 'our': 5, 'ours': 5, 'ourselves': 5,
#                 'they': 6, 'them': 6, 'their': 6, 'themselves': 6,
#                 'that': 7, 'this': 7
#     }
#     ```
#
#     cluster **:** For mention $m_i$:  $p = e_{m_i}$
#
#     mapped **:** For mention $m_i$: $p = \bar e_{m_i}$
#
#     **Entity adapted value: {mapped/cluster}_{$x$}** =  $\frac{\sum_{k=1}^{|C_p|}f_x(C_{pk}, m_i)}{|C_p|}$
#
#     1.
#
#     - $**x$  = pron_pron_c**
#     - $f_x$ = Returns 1 if Pronouns belong to the same class, otherwise 0
#
#     2.
#
#     - $x$ = **pron_pron_nc**
#     - $f_x$ = Returns 1 if Pronouns belong to different classes, otherwise 0
#
#     3.
#
#     - $x$ = **ent_pron**
#     - $f_x$ = Returns 1 if entity-pronoun interaction, otherwise 0
#
#     4.
#
#     - $x$ = **match**
#     - $f_x$ = Returns 1 if mentions completely match, otherwise 0
#
#     5.
#
#     - $x$ = **contains**
#     - $f_x$ = Return 1 if one mention contains the other, otherwise 0
#
#     6.
#
#     - $x$  = **other**
#     - $f_x$ = Return 1 if all other $f$s return 0, otherwise 0

# %%
import pandas as pd
import dtale

# %%
decision_df = pd.read_csv('decision_table.csv')
d = dtale.show(decision_df,subprocess=False, host='localhost')
# Out:
# 2023-10-05 19:15:40,124 - INFO     - D-Tale started at: http://localhost:40000
# 2023-10-05 20:14:01,125 - INFO     - Executing shutdown...
# 2023-10-05 20:14:01,126 - INFO     - Not running with the Werkzeug Server, exiting by searching gc for BaseWSGIServer
